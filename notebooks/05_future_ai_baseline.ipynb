# %% [markdown]
# # 05 — Future AI Baseline (placeholder)
#
# This notebook is a **placeholder** for the future Scientific ML baselines
# described in `docs/scientific_ml_roadmap.md`.
#
# It intentionally does **not** contain any trained model or benchmark
# numbers. When a baseline (POD+regression, POD+LSTM, autoencoder, ...)
# is actually trained:
#
# 1. Implement it under `ai_baseline/baseline_*.py`.
# 2. Run training via `python ai_baseline/train_baseline.py --model <name>`.
# 3. Evaluate on the held-out window via `ai_baseline/evaluate_baseline.py`.
# 4. Then replace this notebook with the actual analysis.

# %%
print('This notebook is a deliberate placeholder. See ai_baseline/README.md.')
# Out:
# This notebook is a deliberate placeholder. See ai_baseline/README.md.
