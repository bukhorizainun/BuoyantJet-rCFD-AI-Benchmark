# %% [markdown]
# # 04 — AI Dataset Preparation
#
# Build NumPy tensors from the snapshot images.
#
# **Honesty note:** the tensors are grayscale intensities in `[0, 1]`, not Kelvin.
# See `scripts/prepare_ai_dataset.py` and `docs/future_ai_extension.md` for the
# planned physical-temperature decoder.

# %%
# !python ..\scripts\prepare_ai_dataset.py --data-root ..\data --out ..\data\processed --config ..\configs\dataset_config.yaml
# Out:
# Traceback (most recent call last):
#   File "D:\AI PROJECTS\AI for CFD & Scientific Machine Learning\BuoyantJet-rCFD-AI-Benchmark\scripts\prepare_ai_dataset.py", line 24, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np, pathlib
P = pathlib.Path('..') / 'data' / 'processed'
cfd  = np.load(P / 'cfd_T_field.npy')
rcfd = np.load(P / 'rcfd_T_field.npy')
print('CFD tensor :', cfd.shape, cfd.dtype, 'range', cfd.min(), cfd.max())
print('rCFD tensor:', rcfd.shape, rcfd.dtype, 'range', rcfd.min(), rcfd.max())
# Out:
# CFD tensor : (630, 128, 128) float32 range 0.11372549 1.0
# rCFD tensor: (600, 128, 128) float32 range 0.11372549 0.99607843
